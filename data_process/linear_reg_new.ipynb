# %%
import torch
from torch import nn
from torch import optim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle
from torchvision import transforms

# %%
# process the data
# take percent for example

folder = "../gyy/"
data = np.zeros(10, dtype=float)
label = np.zeros(1, dtype=float)

for id in range(5):
    filename = "random_4_0.1_1.0_" + str(id) + ".txt"
    new_data = np.genfromtxt(folder + filename)
    data = np.vstack([data, new_data[:, 0:20:2]])
    label = np.hstack([label, new_data[:, -1]])

data = data[1:, :]
label = label[1:]

# %%
'''设置超参数'''
feature_number = 10  # 设置特征数目
out_prediction = 1  # 设置输出数目
learning_rate = 0.001  # 设置学习率
epochs = 100  # 设置训练代数
batch_size = 64

# %%
# 划分数据集
from sklearn.model_selection import train_test_split
 
train_x, val_test_x, train_y, val_test_y = train_test_split(data, label, train_size=0.98,test_size=0.02,
                                                 random_state=2023, shuffle=True)
val_x, test_x, val_y, test_y = train_test_split(val_test_x, val_test_y, train_size=0.5, test_size=0.5,
                                                     random_state=2023, shuffle=True)

# %%
'''mean_X, std_X = train_x.mean(axis=0), train_x.std(axis=0)
mean_Y, std_Y = train_y.mean(), train_y.std()'''

# normalize the train data
from sklearn.preprocessing import StandardScaler
 
scaler1 = StandardScaler()  # 实例化
scaler2 = StandardScaler()
X = scaler1.fit_transform(train_x)  # 标准化特征
Y = scaler2.fit_transform(train_y.reshape(-1, 1))  # 标准化标签

pickle.dump(scaler1, open('scaler_x.pkl','wb'))
pickle.dump(scaler2, open('scaler_y.pkl','wb'))

 
# x = scaler.inverse_transform(X) # 这行代码可以将数据恢复至标准化之前

# %%
train_x = scaler1.transform(train_x)
val_x = scaler1.transform(val_x)
test_x = scaler1.transform(test_x)

train_y = scaler2.transform(train_y.reshape(-1, 1))
val_y = scaler2.transform(val_y.reshape(-1, 1))
# test_y = scaler2.transform(test_y)

# %%
# transform the data type

train_x, val_x, test_x = torch.from_numpy(train_x), torch.from_numpy(val_x), torch.from_numpy(test_x)
train_y, val_y, test_y = torch.from_numpy(train_y), torch.from_numpy(val_y), torch.from_numpy(test_y)

# %%
train = torch.utils.data.TensorDataset(train_x, train_y)
test = torch.utils.data.TensorDataset(test_x, test_y)
validation = torch.utils.data.TensorDataset(val_x, val_y)

'''# 划分训练集测试集与验证集
torch.manual_seed(seed=2023) # 设置随机种子分关键，不然每次划分的数据集都不一样，不利于结果复现
# 大概是98：1：1的比例划分
train_validaion, test = torch.utils.data.random_split(
    torch_dataset,
    [2891000, 59265],
)  # 先将数据集拆分为训练集+验证集
train, validation = torch.utils.data.random_split(
    train_validaion, [2830000, 61000])  # 再将训练集+验证集拆分为训练集，测试集'''
 
# 将训练集划分批次，每batch_size个数据一批（测试集与验证集不划分批次）
train_data = torch.utils.data.DataLoader(train,
                                         batch_size=batch_size,
                                         shuffle=True)

# %%
class Net(torch.nn.Module):
    def __init__(self, n_feature, n_output, n_neuron1, n_neuron2,n_layer):  # n_feature为特征数目，这个数字不能随便取,n_output为特征对应的输出数目，也不能随便取
        self.n_feature=n_feature
        self.n_output=n_output
        self.n_neuron1=n_neuron1
        self.n_neuron2=n_neuron2
        self.n_layer=n_layer
        super(Net, self).__init__()
        self.input_layer = torch.nn.Linear(self.n_feature, self.n_neuron1) # 输入层
        self.hidden1 = torch.nn.Linear(self.n_neuron1, self.n_neuron2) # 1类隐藏层    
        self.hidden2 = torch.nn.Linear(self.n_neuron2, self.n_neuron2) # 2类隐藏
        self.predict = torch.nn.Linear(self.n_neuron2, self.n_output) # 输出层
 
    def forward(self, x):
        '''定义前向传递过程'''
        out = self.input_layer(x)
        out = torch.relu(out) # 使用relu函数非线性激活
        out = self.hidden1(out)
        out = torch.relu(out)
        for i in range(self.n_layer):
            out = self.hidden2(out)
            out = torch.relu(out) 
        out = self.predict( # 回归问题最后一层不需要激活函数
            out
        )  # 除去feature_number与out_prediction不能随便取，隐藏层数与其他神经元数目均可以适当调整以得到最佳预测效果
        return out

# %%
net = Net(n_feature=feature_number,
                      n_output=out_prediction,
                      n_layer=2,
                      n_neuron1=16,
                      n_neuron2=32) # 这里直接确定了隐藏层数目以及神经元数目，实际操作中需要遍历

# optimizer = optim.Adam(net.parameters(), learning_rate)  # 使用Adam算法更新参数
optimizer = optim.SGD(net.parameters(), learning_rate)   # SGD

criteon = torch.nn.MSELoss()  # 均方误差
# criteon = torch.nn.L1Loss()   # L1 loss
# criteon = torch.nn.SmoothL1Loss()   # smoothl1
# criteon = torch.nn.HuberLoss()

val_loss = []
train_loss = []
 
for epoch in range(epochs):  # 整个数据集迭代次数
    net.train() # 启动训练模式
    batch_loss = []
    for batch_idx, (data, target) in enumerate(train_data):
        data = data.to(torch.float32)
        logits = net.forward(data)  # 前向计算结果（预测结果）
        logits = logits.to(torch.float32)
        target = target.to(torch.float32)
        loss = criteon(logits, target)  # 计算损失
        batch_loss.append(loss.item())
        optimizer.zero_grad()  # 梯度清零
        loss.backward()  # 后向传递过程
        optimizer.step()  # 优化权重与偏差矩阵
    train_loss.append(sum(batch_loss) / len(batch_loss))

    logit = []  # 这个是验证集，可以根据验证集的结果进行调参，这里根据验证集的结果选取最优的神经网络层数与神经元数目
    target = []
    net.eval() # 启动测试模式
    for data, targets in validation:  # 输出验证集的平均误差
        data = data.to(torch.float32)
        logits = net.forward(data).detach().numpy()
        targets = targets.detach().numpy()
        target.append(targets[0])
        logit.append(logits[0])

    average_loss = criteon(torch.tensor(logit), torch.tensor(target))
    val_loss.append(average_loss.item())
    print('\nTrain Epoch {}: The Average loss of VAL is {}'.format(epoch, average_loss.item()))
# Out:
# Train Epoch 0: The Average loss of VAL is 0.4649991081700559
#
# Train Epoch 1: The Average loss of VAL is 0.45694690161626866
#
# Train Epoch 2: The Average loss of VAL is 0.448430155196315
#
# Train Epoch 3: The Average loss of VAL is 0.44484470332582493
#
# Train Epoch 4: The Average loss of VAL is 0.44105484148558866
#
# Train Epoch 5: The Average loss of VAL is 0.4382992999019036
#
# Train Epoch 6: The Average loss of VAL is 0.4362111631704536
#
# Train Epoch 7: The Average loss of VAL is 0.4362299623763895
#
# Train Epoch 8: The Average loss of VAL is 0.4333965970222793
#
# Train Epoch 9: The Average loss of VAL is 0.4345571034002211
#
# Train Epoch 10: The Average loss of VAL is 0.43164094708837536
#
# Train Epoch 11: The Average loss of VAL is 0.4314821188998503
#
# Train Epoch 12: The Average loss of VAL is 0.43004028997744836
#
# Train Epoch 13: The Average loss of VAL is 0.4300683845450406
#
# Train Epoch 14: The Average loss of VAL is 0.4302010516885997
#
# Train Epoch 15: The Average loss of VAL is 0.429667756435825
#
# Train Epoch 16: The Average loss of VAL is 0.42931181427279796
#
# Train Epoch 17: The Average loss of VAL is 0.4288377108731994
#
# Train Epoch 18: The Average loss of VAL is 0.42871294353865075
#
# Train Epoch 19: The Average loss of VAL is 0.4283792731162763
#
# Train Epoch 20: The Average loss of VAL is 0.4292295842851933
#
# Train Epoch 21: The Average loss of VAL is 0.42912480603387915
#
# Train Epoch 22: The Average loss of VAL is 0.42855385287734254
#
# Train Epoch 23: The Average loss of VAL is 0.42836656449973554
#
# Train Epoch 24: The Average loss of VAL is 0.42823696861516375
#
# Train Epoch 25: The Average loss of VAL is 0.4287735016597713
#
# Train Epoch 26: The Average loss of VAL is 0.4281268627687954
#
# Train Epoch 27: The Average loss of VAL is 0.428182249704227
#
# Train Epoch 28: The Average loss of VAL is 0.4287760268116289
#
# Train Epoch 29: The Average loss of VAL is 0.42816177715740034
#
# Train Epoch 30: The Average loss of VAL is 0.4279142866509493
#
# Train Epoch 31: The Average loss of VAL is 0.42823414178160235
#
# Train Epoch 32: The Average loss of VAL is 0.42730487951491664
#
# Train Epoch 33: The Average loss of VAL is 0.4273256530624676
#
# Train Epoch 34: The Average loss of VAL is 0.4264974974697472
#
# Train Epoch 35: The Average loss of VAL is 0.42669553436543883
#
# Train Epoch 36: The Average loss of VAL is 0.4271747252996556
#
# Train Epoch 37: The Average loss of VAL is 0.42703363664859734
#
# Train Epoch 38: The Average loss of VAL is 0.4270569949071165
#
# Train Epoch 39: The Average loss of VAL is 0.42707978659668766
#
# Train Epoch 40: The Average loss of VAL is 0.42649487251429574
#
# Train Epoch 41: The Average loss of VAL is 0.4267067064102745
#
# Train Epoch 42: The Average loss of VAL is 0.42625344758087
#
# Train Epoch 43: The Average loss of VAL is 0.4263060746685092
#
# Train Epoch 44: The Average loss of VAL is 0.4272737118885096
#
# Train Epoch 45: The Average loss of VAL is 0.42641671037298606
#
# Train Epoch 46: The Average loss of VAL is 0.4260388828138461
#
# Train Epoch 47: The Average loss of VAL is 0.4271206140259595
#
# Train Epoch 48: The Average loss of VAL is 0.4255943638690118
#
# Train Epoch 49: The Average loss of VAL is 0.4262502985178326
#
# Train Epoch 50: The Average loss of VAL is 0.42595891684851633
#
# Train Epoch 51: The Average loss of VAL is 0.42560381491607296
#
# Train Epoch 52: The Average loss of VAL is 0.42607114199189144
#
# Train Epoch 53: The Average loss of VAL is 0.42561863743202244
#
# Train Epoch 54: The Average loss of VAL is 0.42536665033138266
#
# Train Epoch 55: The Average loss of VAL is 0.4250022530838019
#
# Train Epoch 56: The Average loss of VAL is 0.42534653303466663
#
# Train Epoch 57: The Average loss of VAL is 0.4251197043189844
#
# Train Epoch 58: The Average loss of VAL is 0.4257211487118112
#
# Train Epoch 59: The Average loss of VAL is 0.425703342599771
#
# Train Epoch 60: The Average loss of VAL is 0.4246651365733849
#
# Train Epoch 61: The Average loss of VAL is 0.42475955600226806
#
# Train Epoch 62: The Average loss of VAL is 0.42562834411031086
#
# Train Epoch 63: The Average loss of VAL is 0.42524093438828153
#
# Train Epoch 64: The Average loss of VAL is 0.42542244888017966
#
# Train Epoch 65: The Average loss of VAL is 0.4245599729663083
#
# Train Epoch 66: The Average loss of VAL is 0.4252689092498522
#
# Train Epoch 67: The Average loss of VAL is 0.425470060248807
#
# Train Epoch 68: The Average loss of VAL is 0.424506357186077
#
# Train Epoch 69: The Average loss of VAL is 0.4249362103238493
#
# Train Epoch 70: The Average loss of VAL is 0.4250985643291051
#
# Train Epoch 71: The Average loss of VAL is 0.4245735862358839
#
# Train Epoch 72: The Average loss of VAL is 0.42397025455637394
#
# Train Epoch 73: The Average loss of VAL is 0.42476309733046597
#
# Train Epoch 74: The Average loss of VAL is 0.4255573483155452
#
# Train Epoch 75: The Average loss of VAL is 0.4253899576310736
#
# Train Epoch 76: The Average loss of VAL is 0.4242081255747206
#
# Train Epoch 77: The Average loss of VAL is 0.4237495748134395
#
# Train Epoch 78: The Average loss of VAL is 0.4247403605275941
#
# Train Epoch 79: The Average loss of VAL is 0.4247448579004718
#
# Train Epoch 80: The Average loss of VAL is 0.4251407166216128
#
# Train Epoch 81: The Average loss of VAL is 0.4246360212650973
#
# Train Epoch 82: The Average loss of VAL is 0.42422141218189396
#
# Train Epoch 83: The Average loss of VAL is 0.4245861288655722
#
# Train Epoch 84: The Average loss of VAL is 0.42430238239616974
#
# Train Epoch 85: The Average loss of VAL is 0.42542351571725656
#
# Train Epoch 86: The Average loss of VAL is 0.4241416066698419
#
# Train Epoch 87: The Average loss of VAL is 0.4240749864069853
#
# Train Epoch 88: The Average loss of VAL is 0.4242409009702136
#
# Train Epoch 89: The Average loss of VAL is 0.4249007022237082
#
# Train Epoch 90: The Average loss of VAL is 0.4254070555567454
#
# Train Epoch 91: The Average loss of VAL is 0.4239971056484607
#
# Train Epoch 92: The Average loss of VAL is 0.42524601730094114
#
# Train Epoch 93: The Average loss of VAL is 0.4235169389186199
#
# Train Epoch 94: The Average loss of VAL is 0.42335552429965495
#
# Train Epoch 95: The Average loss of VAL is 0.42395023126710674
#
# Train Epoch 96: The Average loss of VAL is 0.42375069502922474
#
# Train Epoch 97: The Average loss of VAL is 0.4231266863570467
#
# Train Epoch 98: The Average loss of VAL is 0.42365166674310406
#
# Train Epoch 99: The Average loss of VAL is 0.42348037948258227

# %%
prediction = []
label_y = []
net.eval() # 启动测试模式
for test_xs, test_ys in test:
    test_xs = test_xs.to(torch.float32)
    predictions = net(test_xs)
    predictions = predictions.detach().numpy()
    prediction.append(predictions[0])
    test_ys.detach().numpy()
    label_y.append(test_ys.item())

prediction = scaler2.inverse_transform(np.array(prediction).reshape(
    -1, 1)).squeeze()  # 将数据恢复至归一化之前
# test_y = scaler2.inverse_transform(np.array(test_y).reshape(-1, 1))
# label_y = np.array(label_y).reshape(-1, 1)

# 均方误差计算
test_loss = criteon(torch.tensor(prediction ,dtype=torch.float32), torch.tensor(label_y, dtype=torch.float32))
print('测试集均方误差：',test_loss.detach().numpy())
# Out:
# 测试集均方误差： 0.0009425235

# %%
# 可视化
l_lim, r_lim = -0.2, 0.3
plt.figure()
plt.scatter(test_y, prediction, color='red', s=1)
plt.plot([l_lim, r_lim], [l_lim, r_lim], color='black', linestyle='-')
plt.xlim([l_lim, r_lim])
plt.ylim([l_lim, r_lim])
plt.xlabel('true')
plt.ylabel('prediction')
plt.title('true vs prection')
plt.show()

# %%
# 打印参数
for _,param in enumerate(net.parameters()):
    print(param)
    print('----------------')
# Out:
# Parameter containing:
# tensor([[ 0.3307, -0.0869, -0.0368, -0.1516,  0.0055,  0.1181,  0.1500,  0.2487,
#           0.2450,  0.0366],
#         [ 0.2319, -0.0406, -0.1345,  0.0885,  0.1582, -0.1574, -0.2461, -0.0776,
#          -0.0507, -0.2758],
#         [-0.0622,  0.2883, -0.1498, -0.3060,  0.2160, -0.2637, -0.0732,  0.0736,
#          -0.1453,  0.0073],
#         [-0.2720, -0.2076, -0.1172,  0.0299,  0.0087, -0.0064,  0.2083, -0.0202,
#          -0.0875, -0.1777],
#         [ 0.0390,  0.2275, -0.0304,  0.0599, -0.0064, -0.0879,  0.0941, -0.3094,
#           0.1883, -0.0156],
#         [-0.3409,  0.0525, -0.1405,  0.0830,  0.0117,  0.1949,  0.1436,  0.0437,
#           0.2264,  0.0504],
#         [ 0.0771, -0.1535, -0.0066,  0.1552,  0.0888,  0.0291,  0.1458,  0.0817,
#          -0.0949,  0.1415],
#         [ 0.0806,  0.0835,  0.2199,  0.1676, -0.0901, -0.1485, -0.2630,  0.0209,
#          -0.1580, -0.1790],
#         [ 0.2841, -0.3003, -0.3125, -0.0782,  0.3121, -0.2449, -0.0308,  0.0916,
#           0.1092,  0.2543],
#         [-0.1462, -0.0589, -0.2666, -0.0359, -0.3005,  0.1741,  0.2341, -0.2193,
#           0.0640, -0.0803],
#         [ 0.1505, -0.0572, -0.1293,  0.1380, -0.2438,  0.1277,  0.2308, -0.0612,
#          -0.1840, -0.1646],
#         [-0.0246,  0.1330,  0.1591,  0.1405,  0.1124,  0.0895, -0.0142,  0.2054,
#           0.2860, -0.2146],
#         [ 0.1247,  0.0918, -0.0997,  0.3490, -0.1159,  0.2741,  0.2890, -0.1264,
#           0.1422,  0.0292],
#         [ 0.2000, -0.2780, -0.0414,  0.0062, -0.1216,  0.2462,  0.2057,  0.0860,
#           0.2164,  0.1744],
#         [-0.3313, -0.3024, -0.0199,  0.1039, -0.0282, -0.2837, -0.1929, -0.1805,
#          -0.1537, -0.2299],
#         [ 0.0480, -0.2450, -0.0888, -0.1854,  0.0475,  0.0135,  0.2055, -0.2259,
#          -0.0729,  0.2096]], requires_grad=True)
# ----------------
# Parameter containing:
# tensor([ 0.0278,  0.1899, -0.0771, -0.2200, -0.0277, -0.2530, -0.2605,  0.0121,
#         -0.1203, -0.0706, -0.0513,  0.2926,  0.0366,  0.0805,  0.1932, -0.0683],
#        requires_grad=True)
# ----------------
# Parameter containing:
# tensor([[ 0.2778,  0.0810, -0.2412, -0.2486, -0.0775, -0.1206,  0.1669,  0.0443,
#           0.2934, -0.1542,  0.1625,  0.2475,  0.1510, -0.0212, -0.2043, -0.0502]],
#        requires_grad=True)
# ----------------
# Parameter containing:
# tensor([-0.0892], requires_grad=True)
# ----------------

# %%
# 绘制train loss
plt.cla()
x1 = range(1, epochs + 1)
y1 = train_loss
plt.title('Train loss vs. epoches', fontsize=20)
plt.plot(x1, y1, '.-')
plt.xlabel('epoches', fontsize=20)
plt.ylabel('Train loss', fontsize=20)
plt.grid()
'''plt.savefig("./lossAndacc/Train_loss.png")
plt.savefig("./lossAndacc/Train_loss.png")'''
plt.show()

# %%
# 绘制val loss
plt.cla()
x1 = range(1, epochs+1)
y1 = val_loss
plt.title('Val loss vs. epoches', fontsize=20)
plt.plot(x1, y1, '.-')
plt.xlabel('epoches', fontsize=20)
plt.ylabel('Val loss', fontsize=20)
plt.grid()
'''plt.savefig("./lossAndacc/Train_loss.png")
plt.savefig("./lossAndacc/Train_loss.png")'''
plt.show()

# %%
# save & load the model

path = "./model/deep"
file_name = "/sota_for_SGD.pkl"
torch.save(net, path + file_name)

'''
model = torch.load(path + file_name)
model.eval()
'''
# Out:
# '\nmodel = torch.load(path + file_name)\nmodel.eval()\n'
